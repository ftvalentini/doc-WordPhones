# %%
import pickle

file = "output/allosaurus_es_sr16000_ipa.pkl"

with open(file, "rb") as f:
    data = pickle.load(f)

# %%
import re

def parse_allosaurus_output(output: str):
    parsed = []
    for line in output.strip().splitlines():
        parts = line.split(maxsplit=2)
        time = float(parts[0])
        duration = float(parts[1])
        # Regex to extract phoneme and probability pairs
        phoneme_probs = re.findall(r'(\S+)\s*\(([\d.]+)\)', parts[2])
        phoneme_probs = [(p, float(prob)) for p, prob in phoneme_probs]
        parsed.append({
            "time": time,
            "duration": duration,
            "phones": phoneme_probs
        })
    return parsed


def get_most_probable_phones(parsed_output):
    most_probable = []
    for entry in parsed_output:
        if entry["phones"]:
            # # Sort phonemes by probability and take the most probable one
            # most_probable_phoneme = max(entry["phonemes"], key=lambda x: x[1])
            # They are already sorted by probability, so we can take the first one
            most_probable_phoneme = entry["phones"][0][0]
            most_probable.append(most_probable_phoneme)
    return most_probable

# %%
parsed = {}
most_probable = {}
for k, v in data.items():
    parsed[k] = parse_allosaurus_output(v)
    most_probable[k] = get_most_probable_phones(parsed[k])

# %%
import pandas as pd

# Cols: file_name, phones
df_phones = pd.DataFrame(most_probable.items(), columns=["file_name", "phone_list"])

# %%
# Extract data from file_name e.g. desde_es061900_es.Argentina.wav -> desde (word), es061900 (id), es.Argentina (accent)
def parse_file_name(file_name):
    parts = file_name.split('_')
    word = parts[0]
    id_ = parts[1]
    accent = '_'.join(parts[2:]).replace('.wav', '')
    return word, id_, accent

df_phones[['word', 'id', 'accent']] = df_phones['file_name'].apply(parse_file_name).apply(pd.Series)

# %%
df_phones["phones"] = df_phones["phone_list"].apply(lambda x: " ".join(x))

# %%
df_phones.head()
# Out:
#                              file_name                         phone_list  \
# 0    glamour_es096711_es.Argentina.wav           [d, iː, l̪, a, m, uə, ɾ]
# 1      redactar_es164583_es.Mexico.wav  [ɾ, e, b, a, t͡ɕ, iː, t, a, ɾ, a]
# 2  descorrer_es061733_es.Argentina.wav       [pʲ, ɪ, s, k, o, ɾ, ʀ, æ, ɾ]
# 3   enemigo_es075782_es.Castellano.wav       [lʲ, e, n, e, m, ɪ, i, k, o]
# 4      indignar_es108278_es.Mexico.wav          [iː, n, d, i, g, n, ɪ, ɾ]
#
#         word        id         accent                  phones
# 0    glamour  es096711   es.Argentina        d iː l̪ a m uə ɾ
# 1   redactar  es164583      es.Mexico  ɾ e b a t͡ɕ iː t a ɾ a
# 2  descorrer  es061733   es.Argentina      pʲ ɪ s k o ɾ ʀ æ ɾ
# 3    enemigo  es075782  es.Castellano      lʲ e n e m ɪ i k o
# 4   indignar  es108278      es.Mexico        iː n d i g n ɪ ɾ

# %%
# Train logistic regression model to predict accent based on phones
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer

# from gruut_ipa import Pronunciation

# def phone_tokenizer(text):
#     return [x.text for x in Pronunciation.from_string(text).phones]

# %%
import numpy as np
import pandas as pd

vectorizer_uni = CountVectorizer(
    lowercase=False,
    # tokenizer=phone_tokenizer,
    ngram_range=(1, 1),
    analyzer=lambda x: x,
    min_df=5,  # Minimum document frequency
    binary=True,  # Binary counts (presence/absence of n-grams)
)

X_vectorized = vectorizer_uni.fit_transform(df_phones["phone_list"].values)
y = df_phones["accent"].values
model = LogisticRegression(max_iter=1000, random_state=33)
model.fit(X_vectorized, y);

# %%
# Inspect largest coefficients per class:
def get_top_features_per_class(model, vectorizer, top_n=10):
    feature_names = vectorizer.get_feature_names_out()
    coefs = model.coef_
    classes = model.classes_

    top_features = {}
    for i, class_label in enumerate(classes):
        class_coefs = coefs[i]
        # # Get indices of top features in absolute value
        # top_indices = np.argsort(np.abs(class_coefs))[-top_n:][::-1]
        # Get indices of top features in absolute value
        top_indices = np.argsort(class_coefs)[-top_n:][::-1]
        # Get feature names and their corresponding coefficients
        top_features[class_label] = [(feature_names[idx], class_coefs[idx]) for idx in top_indices]
    return top_features

def contains_subsequence(data, pattern):
    m, n = len(data), len(pattern)
    if n == 0:
        return True   # empty pattern “always” matches
    if n > m:
        return False  # pattern longer than data can’t match
    # slide a window of length n over data
    for i in range(m - n + 1):
        if data[i:i+n] == pattern:
            return True
    return False

def get_examples_for_top_features(df, top_features, n_examples=3):
    examples = {}
    for class_label, features in top_features.items():
        examples[class_label] = {}
        for feature, coef in features:
            # Get rows where the feature appears
            rows = df[df['phone_list'].apply(lambda x: contains_subsequence(x, feature.split()))]
            # Take up to n_examples in format "word (phones), word (phones), ..."
            res = rows["word"] + " (" + rows["phones"] + ")"
            # Store the examples
            examples[class_label][feature] = ", ".join(
                res.head(n_examples).values
            )
            
    return examples


top_features = get_top_features_per_class(model, vectorizer_uni, top_n=10)
examples = get_examples_for_top_features(df_phones, top_features, n_examples=3)

# For each accent, show the top 10 phones, coefficients and examples:
for acc, features in top_features.items():
    print(f"Accent: {acc}")
    for feature, coef in features:
        print(f"    {feature}, ({coef:.4f})")
        print(f"        {examples[acc][feature]}")
        # print(f"        {examples[acc][feature].replace(', ', '\n')}")
    print()
# Out:
# Accent: es.Argentina
#     ʐ, (1.9908)
#         lacayo (l a k a ʐ o), zambullir (t a m uə ʐ i e ɾ), mudo (tʂ o ŋ ʐ o)
#     sː, (1.3932)
#         preceder (p a ɾ e sː e æ ð æ ɾ), presentador (b̞ ɾ i sː e n t a ð o ɾ), acertijo (ɒ sː e ɾ t i x o)
#     ʋ, (1.3162)
#         próspero (tʂ ɨ ɾ l o uə ʋ p e ɾ o), suspirar (s u ʋ p i lʲ a ɾ), perezosa (e ɾʲ e t ɒ o ʋ ʂ a ɪ)
#     ɻ, (0.7557)
#         lógico (ɪ ɻ o uə x i k o), bocacalle (b uə k a ɾ k a ɻ e), patológico (p ɒ t uə o ɻ o x i k ʌ)
#     ʊ, (0.5874)
#         estructurar (ɪ s t ɾ ʊ k t uə ɾ a ɾ), trailer (ʊ r ɒ ɟ iː lʲ e), hispanoamérica (ɪ s p a n ʊ a m e ɪ ɾʲ i k a)
#     ә, (0.5655)
#         hombro (ɳ ә b j ɒ o), competición (k o m ә p e ɪ t̪ i ɕ ɪ ə n), alambre (a lː æ m ә b ɾ e ɪ)
#     æ, (0.4881)
#         descorrer (pʲ ɪ s k o ɾ ʀ æ ɾ), preceder (p a ɾ e sː e æ ð æ ɾ), oriente (o ɾ j æ ɳ t e)
#     v̞ʲ, (0.4476)
#         pesticida (v̞ʲ e s t iː ɕ i ð ɪ), rebasar (t̪ ɾ v̞ʲ e ɪ b̞ a ʂ a ɾ), permisivo (v̞ʲ ɒ ɪ ɾ m iː s̪ iː p uə o)
#     tː, (0.3895)
#         papi (a tː iː), sector (s̪ ɪ k tː ɔ ɾ ə), marte (m a ɾ ʌ tː e)
#     v, (0.3529)
#         biblioteca (pʲ i v lʲ j o t e k a), aprovechado (ʔ ɒ p ɾ o v e ɪ tɕʰ i ɒ d o), abril (ʔ ɒ v uə ɾ iː)
#
# Accent: es.Castellano
#     tsʰ, (1.3878)
#         pizzería (i tsʰ ɹ̩ ɾ i æ), tránsfuga (ɾ a n tsʰ f uə g k ʌ), lanzallamas (l̪ l ʌ n tsʰ a tɕ i a m a)
#     fʲ, (1.2221)
#         Macedonia (m a fʲ e ɾ o ɴ n j a), ejecutable (ɾʲ e fʲ e k uə t a ɾ lʲ e), ínfimo (i n fʲ ɪ m o)
#     kʰ, (0.9987)
#         crujido (p uə ɾ uə kʰ i tʂ o), pájaro (p ɒ ʂ kʰ a tʂ ɨ ə), ingestión (tɕ i n kʰ ʁ e s t iː ə n)
#     tʰ, (0.9257)
#         cañaveral (tʂ a ɲ ɒ b̞ e ɪ ɾ tʰ a), boite (uə ʌ tʰ), infringir (i ɴ p ɾ ʌ n tʰ i ɪ ɾ)
#     dʲ, (0.8762)
#         dialecto (dʲ j a lʲ e k t ɔ), diario (dʲ iː a l ɪ j o uə), diócesis (dʲ iː o sː e s̪ iː s)
#     t̪ʰ, (0.8724)
#         jacarandá (t̪ʰ a ɡ̤ a ɾ ɒ ɳ d ɒ), ebriedad (t̪ʰ e b̞ ɾʲ iː g e t̪ a ɾ), ramada (t̪ʰ i ɾ ɒ m ɒ ð ɒ)
#     pʰ, (0.8108)
#         expropiar (e k s p ɾ o pʰ j æ ɾ), vatio (b̞ a pʰ i ə), repugnar (g ɾ e ɪ p uə pʰ uː l a ɾ)
#     rː, (0.8046)
#         becerro (b e ts e ɾ rː o), transcurrir (t ɾ a ɪ n iː s k uə rː j ə s), escurridizo (e s k uə rː i ɪ t̪ i s ə)
#     d̪, (0.7467)
#         rábano (d̪ ɨ ɾ r ɒ b̞ ɒ ɳ u ŋ̟), postergar (ʔ uə o s d̪ e ɾ g a ɾ), rato (d̪ ɨ ɾ r a t̪ u)
#     d͡ʒ̤, (0.6668)
#         fallar (f a d͡ʒ̤ a ɾ), chat (d͡ʒ̤ ɒ), pacha (ɒ d͡ʒ̤ ɻ̩)
#
# Accent: es.Mexico
#     ɡ̤, (0.7526)
#         jacarandá (t̪ʰ a ɡ̤ a ɾ ɒ ɳ d ɒ), galardonar (ɡ̤ ɒ l ɒ ɾ t̪ o ɳ a), galeno (ɡ̤ a ɪ l i ɴ o)
#     ɔ̃, (0.7261)
#         autonómico (ɒ u uə t uə o ɴ ɔ̃ ŋ b i k ʌ), oneroso (ɔ̃ n j e ɾ o uə ʂ o), pomelo (ɔ̃ m e ɪ l o)
#     tɕʰ, (0.5768)
#         aprovechado (ʔ ɒ p ɾ o v e ɪ tɕʰ i ɒ d o), pinche (b̞ i n tɕʰ iː), genialidad (tɕʰ e n iː j a l i ð a ð)
#     k̟ʲ, (0.5586)
#         taquicardia (t a k k̟ʲ iː k a ɾ t̪ j a), parque (b̞ a ɾ k̟ʲ iː), marroquí (m ɒ t̪ ɾ o uə k̟ʲ iː)
#     d͡ʒ, (0.5286)
#         ayunas (ɒ d͡ʒ o n ɪ), taquilla (d ɒ ɪ t̪ i d͡ʒ a), llaga (d͡ʒ i ɒ g ʌ)
#     v, (0.5176)
#         biblioteca (pʲ i v lʲ j o t e k a), aprovechado (ʔ ɒ p ɾ o v e ɪ tɕʰ i ɒ d o), abril (ʔ ɒ v uə ɾ iː)
#     ɑ, (0.4898)
#         estimable (ɛ s t̪ i m ɑ ɹ b̞ l i), snob (ɪ s n ɑ tʰ), accionar (a p s ɯ j o uə n ɑ ɾ)
#     g, (0.4708)
#         indignar (iː n d i g n ɪ ɾ), estancado (e s t a n g a ð o), contentar (g o n t e n t a ɾ)
#     mʲ, (0.4523)
#         negativo (mʲ e ɡ a t i b̞ o), vulnerar (b̞ uə b̞ i mʲ e ɾ a ɾ ɪ), inercia (i mʲ e æ ɾ ʌ ɕ j a)
#     ɟ, (0.4123)
#         trailer (ʊ r ɒ ɟ iː lʲ e), agregar (ʁ a j ɟ ɨ r ɤ̆ ɡ̤ ɒ ɾ), arreglado (ʔ a ɾ ɪ ɟ iː l ɒ l o)

# %%
# same with bigrams:
vectorizer_bi = CountVectorizer(
    lowercase=False,
    analyzer='word',       # we’re working at word level
    tokenizer=lambda x: x,    # don’t split strings—already lists
    preprocessor=lambda x: x, # don’t lowercase or strip
    token_pattern=None,    # disable the default regex‑based tokenizer
    ngram_range=(2,2),    # only bigrams
    min_df=5,     # Minimum document frequency
    binary=True,  # Binary counts (presence/absence of n-grams)
)

X_vectorized = vectorizer_bi.fit_transform(df_phones["phone_list"].values)
y = df_phones["accent"].values
model = LogisticRegression(max_iter=1000, random_state=33)
model.fit(X_vectorized, y);

top_features = get_top_features_per_class(model, vectorizer_bi, top_n=10)
examples = get_examples_for_top_features(df_phones, top_features, n_examples=3)

# For each accent, show the top 10 phones, coefficients and examples:
for acc, features in top_features.items():
    print(f"Accent: {acc}")
    for feature, coef in features:
        print(f"    {feature}, ({coef:.4f})")
        print(f"        {examples[acc][feature]}")
        # print(f"        {examples[acc][feature].replace(', ', '\n')}")
    print()
# Out:
# Accent: es.Argentina
#     ɕ t, (2.7409)
#         destajo (d e ɕ t a x uə), cronista (uə ɾ o n iː ɪ ɕ t æ), cubista (uə b̞ i ɪ ɕ t a)
#     ɕ m, (2.6909)
#         organismo (ʔ uə ɾ ɹ̩ ɡ a n i ɕ m uə), favoritismo (s̪ a b̞ o l i t i ɕ m uə), cataclismo (t͡ɕ ɒ t̪ a ɪ k ʌ l i ɕ m o)
#     ɕ k, (2.2045)
#         risco (t̪ ɾ i ɕ k o), morisco (m uə ɾ i ɕ k ɔ), descafeinado (pʲ e ɕ k a f e i n a ð o)
#     uə ʋ, (2.1019)
#         próspero (tʂ ɨ ɾ l o uə ʋ p e ɾ o), apostillar (a p uə ʋ t̪ i ʐ a ɾ), insufrible (i n s uə ʋ f ɾ i b̞ lʲ e ɪ)
#     ʐ a, (2.0773)
#         astilla (ɒ t i ʐ a), grosella (g ɾ o ʂ e ʐ a), apoyar (ʔ a p uə ʐ a ɾ)
#     ʐ e, (1.8774)
#         banderillero (b a n d e ɾ i ʐ e ɾ o), proyectar (ɾ o ʐ e k t a ɾ), creyente (k ɾʲ e ʐ e æ n t e)
#     z æ, (1.8648)
#         paladar (b a j lː a z æ ɾ), ladilla (lː a ɪ ð i z æ), tabla (t a b iː z æ)
#     iː ɾʲ, (1.8131)
#         escrito (e s k iː ɾʲ i t o), creación (tʂ iː ɾʲ e æ sː j o n), creta (g iː ɾʲ e t a)
#     ɪ ɾʲ, (1.7263)
#         notaría (n o uə t a ɪ ɾʲ i j a), hispanoamérica (ɪ s p a n ʊ a m e ɪ ɾʲ i k a), prorrata (ɪ ɾʲ o uə ɾ a t a)
#     sː a, (1.6838)
#         cazatalentos (k a sː a t a ɪ lʲ e n t o s), desinteresadamente (pʲ e s i n t e ɾʲ e sː a ð a m e n t e), desandar (ð ɪ sː a n d a ɾ)
#
# Accent: es.Castellano
#     tɕ ʌ, (1.5661)
#         lavavajillas (lʲ ɒ v ʌ b̞ a o x i tɕ ʌ), agrietar (ɒ tɕ ʌ ɾ j e t a ɾ), espinilla (e s p i n iː tɕ ʌ)
#     t̪ʰ ɒ, (1.5139)
#         pedir (t̪ʰ ɒ ð i ɾ), cojo (t͡ɕ ɛ t̪ t̪ʰ ɒ), tentempié (t̪ʰ ɒ n t ʌ m p i ə)
#     j ʌ, (1.4871)
#         resolución (n t ɾ e s uə o l uə s̪ j ʌ n), ciempiés (s̪ j ʌ m p j e s), enviado (æ n v j ʌ ð o)
#     lː ʌ, (1.4801)
#         ginecólogo (tɕʰ i n e ɪ k o l lː ʌ ʁ o), título (t iː t uə lʲ lː ʌ o), colonizar (k͡p̚ uə o l̪ lː ʌ ɴ i tsʰ a ɾ)
#     ɹ̩ s, (1.4705)
#         abstener (ɒ p ɹ̩ s t ə n iː v), zurcir (s uə b̞ ɹ̩ s i ɾ), fiestas (ij j ɛ s ð ɹ̩ s)
#     dʲ e, (1.4599)
#         derrochar (dʲ e ɾ o t͡ʃʲ æ ɾ ɪ), desmoronar (dʲ e s m o ɾ o n ɪ ɾ), hermanastro (dʲ e ɾ ʌ e m a n a s t ɾ o)
#     n ð, (1.4368)
#         desligar (n ð e s ɻ̩ lʲ i k a ɾ), deshidratar (n ð e s̪ i iː ð ɒ lʲ a t a ɾ), desconcertante (n ð e s k o n tʰ e ɾ t a n t e)
#     a dʲ, (1.4276)
#         batalla (b̥ a t a dʲ i æ), medallón (m e ð a dʲ o n), avasallar (ʔ ɒ b̞ a ɒ ʂ a dʲ i æ ɾ uə)
#     ɪ ʌ, (1.4230)
#         personificación (e ɾ e s o ɴ n i f i k a s ɪ ʌ n), farmacología (f a ɾ m a ɪ k o l o uə x ɪ ʌ), posesión (p ɒ ʂ e ɪ s ɪ ʌ n)
#     b̤ ɛ, (1.4136)
#         ultrajar (ʔ uə u l̪ lʲ b̤ ɛ ɾ a x ɒ ɾ), franja (b̤ ɛ ɾ ɒ ŋ iː s̪ k͡p̚ ɒ), retractar (b̤ ɛ ɾ r ij i t̪ ɛ ɾ a ɡ̤ iː t̪ ɒ)
#
# Accent: es.Mexico
#     z g, (1.7377)
#         rasgos (ɾ a z g o s), desgana (d e z g a n ɪ), riesgoso (p ɾ j e z g o ʂ o)
#     ɛ e, (1.6674)
#         excusado (ɛ e k s k u s a ð o), exacerbar (e ɛ e k s a s e æ ɾ ə b̥ a ɾ), expropiar (ɛ e k s p ɾ o uə p j a ɾ)
#     z m, (1.5025)
#         sismógrafo (s i z m o ɡ ɾ ɪ f uə), seísmo (s̪ e ɪ i iː z m uə o), analfabetismo (ɒ n ɴ n ɒ l̪ f a b̞ e ɪ t i z m)
#     ɳ f, (1.3961)
#         anfibio (ɒ ɴ ɳ f i b iː o), confidencia (k͡p̚ ɔ ɳ f i ð ʌ n ɕ i a), anfiteatro (ɒ n ɳ f i t e a t̪ ɾ o)
#     ɔ̃ ɾ, (1.3465)
#         corpóreo (k ɔ̃ ɾ p o ɾ ɪ o), Uruguay (ɔ̃ ɾ uː k uə a i), corto (k ɔ̃ ɾ t uə)
#     s̪ k, (1.2727)
#         vizconde (b̥ i s̪ k ɔ n d ɪ), bizcocho (b i s̪ k ɔ t͡ɕ o uə), transcurso (ɾ a n s̪ k uə ɾ uː ʂ a ŋ)
#     ɾ d, (1.2529)
#         engordar (tʲ e n ɡ uə o ɾ d a n), verdugo (b̞ e ɪ ɾ d uə p uə o), guardería (k͡p̚ uə o ɒ ɾ d ʌ ɾ i j a)
#     z b, (1.2510)
#         esbozar (e z b o uə s a ɾ), béisbol (b̞ e ɪ z b uə l), esbozo (e z b uə s o)
#     ɛ s, (1.2321)
#         estimulante (ɛ s t iː i m uə l̪ l a n t e), espray (ɛ s p ɾ ɒ), estímulo (ɛ s t i m uə lʲ o)
#     z ɡ, (1.2312)
#         riesgo (ɾ j e z ɡ o), disgustado (ð e z ɡ uə s t a ð o), disgregar (d i z ɡ e ɾ e ɡ a ɾ)

# %%
df_phones.head(2)
# Out:
#                            file_name                         phone_list  \
# 0  glamour_es096711_es.Argentina.wav           [d, iː, l̪, a, m, uə, ɾ]
# 1    redactar_es164583_es.Mexico.wav  [ɾ, e, b, a, t͡ɕ, iː, t, a, ɾ, a]
#
#        word        id        accent                  phones
# 0   glamour  es096711  es.Argentina        d iː l̪ a m uə ɾ
# 1  redactar  es164583     es.Mexico  ɾ e b a t͡ɕ iː t a ɾ a

# %%
# Create df with cols: word, accents (N cols), phones:
df_words = df_phones.pivot_table(index=['word', 'id'], columns='accent', values='phones', aggfunc='first').reset_index()
df_words.query("word == 'usa'")
# Out:
# accent word        id es.Argentina  \
# 18042   usa  es195566      ʔ u t a
#
# accent                                     es.Castellano es.Mexico
# 18042   ɪ s t a ð o s u n i ð o uə s ð e ə a m e ɾ i k a  uə s ɒ n

# %%
import Levenshtein
from itertools import combinations

accent_cols = [col for col in df_words.columns if col not in ['word', 'id']]
results = []
for _, row in df_words.iterrows():
    word = row['word']
    wordid = row['id']
    for acc1, acc2 in combinations(accent_cols, 2):
        phones1 = row[acc1]
        phones2 = row[acc2]
        if pd.isna(phones1) or pd.isna(phones2) or len(phones1) == 0 or len(phones2) == 0:
            dist = None
        else:
            dist = Levenshtein.distance(row[acc1], row[acc2])
        results.append({
            'word': word,
            'wordid': wordid,
            'accent_pair': f'{acc1}-{acc2}',
            'phones_pair': f'[{phones1}]\n[{phones2}]',
            'l_distance': dist,
            # 'n_phones': TODO, # using phone_list
        })

# %%
from IPython.display import display, HTML

def pretty_print(df):
    return display( HTML( df.to_html().replace("\\n","<br>") ) )

# %%
df_dist = pd.DataFrame(results)
dd = df_dist.sort_values(by='l_distance', ascending=False) # TODO should use IDs!
pretty_print(dd.head(10))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>word</th>
#       <th>wordid</th>
#       <th>accent_pair</th>
#       <th>phones_pair</th>
#       <th>l_distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>54126</th>
#       <td>usa</td>
#       <td>es195566</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[ʔ u t a]<br>[ɪ s t a ð o s u n i ð o uə s ð e ə a m e ɾ i k a]</td>
#       <td>43.0</td>
#     </tr>
#     <tr>
#       <th>54128</th>
#       <td>usa</td>
#       <td>es195566</td>
#       <td>es.Castellano-es.Mexico</td>
#       <td>[ɪ s t a ð o s u n i ð o uə s ð e ə a m e ɾ i k a]<br>[uə s ɒ n]</td>
#       <td>42.0</td>
#     </tr>
#     <tr>
#       <th>44846</th>
#       <td>rae</td>
#       <td>es161488</td>
#       <td>es.Castellano-es.Mexico</td>
#       <td>[b ɾ e a l a k a ð e m j ɪ e s p a ɲ o n ɪ]<br>[d̪ ʌ r ɒ]</td>
#       <td>38.0</td>
#     </tr>
#     <tr>
#       <th>44844</th>
#       <td>rae</td>
#       <td>es161488</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[d̪ uə ɾ a]<br>[b ɾ e a l a k a ð e m j ɪ e s p a ɲ o n ɪ]</td>
#       <td>37.0</td>
#     </tr>
#     <tr>
#       <th>53900</th>
#       <td>ue</td>
#       <td>es194697</td>
#       <td>es.Castellano-es.Mexico</td>
#       <td>[u n j o n e u uə ɾ o p e ɪ a]<br>[k͡p̚ e]</td>
#       <td>26.0</td>
#     </tr>
#     <tr>
#       <th>53898</th>
#       <td>ue</td>
#       <td>es194697</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[ʔ w e]<br>[u n j o n e u uə ɾ o p e ɪ a]</td>
#       <td>25.0</td>
#     </tr>
#     <tr>
#       <th>26226</th>
#       <td>galgo</td>
#       <td>es094728</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[g a l uə ɡ o]<br>[t̪ʰ iː ɴ ɡ̤ ɒ s̪ iː k͡p̚ uə o]</td>
#       <td>23.0</td>
#     </tr>
#     <tr>
#       <th>546</th>
#       <td>abrevadero</td>
#       <td>es001401</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[ʔ ɒ b̞ ʌ ɾ i ɪ b̞ a ð i ɾ o]<br>[ɒ p uə ɾʲ e b̞ ɒ o t̪ uə e ɪ tʂ o uə]</td>
#       <td>23.0</td>
#     </tr>
#     <tr>
#       <th>4898</th>
#       <td>arrebatado</td>
#       <td>es017301</td>
#       <td>es.Castellano-es.Mexico</td>
#       <td>[ɒ tʂ ɾ ʌ ɪ b̞ a n t͡ɕ i a ŋ d o]<br>[ʏ b̞ ɒ t a]</td>
#       <td>23.0</td>
#     </tr>
#     <tr>
#       <th>15492</th>
#       <td>cuidador</td>
#       <td>es055637</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[w i ð æ ð o ɾ]<br>[k͡p̚ uə e ɪ tɕ i a ts ɒ o tʂ ɹ̩]</td>
#       <td>23.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
dd = df_dist.sort_values(by='l_distance', ascending=False).query("l_distance < 20").head(20)
pretty_print(dd)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>word</th>
#       <th>wordid</th>
#       <th>accent_pair</th>
#       <th>phones_pair</th>
#       <th>l_distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>42531</th>
#       <td>positivismo</td>
#       <td>es153631</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[ʔ o s̪ iː t̪ i b̞ e m a]<br>[p o ʂ uə ɪ t iː b̞ iː ʂ ɻ̩ m ɒ o]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>12117</th>
#       <td>cohesionar</td>
#       <td>es043302</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[o ɪ s̪ j o n æ ɾ]<br>[k͡p̚ uə o l̪ b̞ e ɕ i o n a]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>548</th>
#       <td>abrevadero</td>
#       <td>es001401</td>
#       <td>es.Castellano-es.Mexico</td>
#       <td>[ɒ p uə ɾʲ e b̞ ɒ o t̪ uə e ɪ tʂ o uə]<br>[ʔ ɒ b ʌ ɾ e ɪ b̞ a d e ɪ ɾ uə]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>29046</th>
#       <td>ignominia</td>
#       <td>es104798</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[i k͡p̚ ʌ n ɴ d ɒ o m iː ɲ i æ n]<br>[i n o m ɪ n iː ə]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>26235</th>
#       <td>gallego</td>
#       <td>es094764</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[d æ tʂ e ɡ o]<br>[iː ɴ k a d͡ʒ i e k͡p̚ uə o]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>8442</th>
#       <td>bárbaro</td>
#       <td>es023980</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[b̥ ʌ tʰ]<br>[n p a ʂ ɻ̩ p a ɾ o uə]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>4984</th>
#       <td>arriesgado</td>
#       <td>es017608</td>
#       <td>es.Argentina-es.Mexico</td>
#       <td>[a ɾ i e ɕ a ð uə]<br>[ʔ ɒ k͡p̚ ɾ j e ʂ g i æ s o ŋ]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>13486</th>
#       <td>conocedor</td>
#       <td>es048447</td>
#       <td>es.Argentina-es.Mexico</td>
#       <td>[k͡p̚ o n o f ɪ ð uə o ɾ]<br>[k uə o n ɴ n o uə ɕ i e d a ɒ ð ɾ]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>10317</th>
#       <td>caverna</td>
#       <td>es036728</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[ɾ]<br>[t͡ɕ ɒ a b̞ e ɾ ә n ɪ]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>53012</th>
#       <td>transparencia</td>
#       <td>es191843</td>
#       <td>es.Castellano-es.Mexico</td>
#       <td>[t ɾ a ɪ e ɳ n ә s p a lʲ i n tʰ i a]<br>[ɾ ɒ n p a ɾ ʌ e n ɕ i a]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>1258</th>
#       <td>adalid</td>
#       <td>es003960</td>
#       <td>es.Argentina-es.Mexico</td>
#       <td>[ʔ ɒ b a ɪ lː i ɪ j uə b̥ ʌ]<br>[ɒ ð ɒ lʲ i]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>51577</th>
#       <td>tecnicismo</td>
#       <td>es186213</td>
#       <td>es.Argentina-es.Mexico</td>
#       <td>[ð e k ʌ m i s i m a]<br>[tʂ e k͡p̚ iː ɴ n iː ɕ i s ɻ̩ m uə]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>21025</th>
#       <td>enganchado</td>
#       <td>es076175</td>
#       <td>es.Argentina-es.Mexico</td>
#       <td>[i ɡ a n ɳ t͡ʃʲ a ð uə o]<br>[ʔ i n iː ɴ g ɡ æ n tɕʰ i a ð o]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>26829</th>
#       <td>gobernador</td>
#       <td>es096906</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[k͡p̚ o l̪ ts ɒ ɪ ɾ ʌ ɳ æ tʂ o ɾ]<br>[ɡ̤ ɔ v æ ɾ r ә m ɴ ɒ t̪ ɒ]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>3216</th>
#       <td>ambulancia</td>
#       <td>es011201</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[a m b uə lʲ a n s i a]<br>[ʔ ɒ ɳ ə n p uə l̪ lʲ ʌ n iː t͡ɕ i a]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>49811</th>
#       <td>sobrecargo</td>
#       <td>es179664</td>
#       <td>es.Castellano-es.Mexico</td>
#       <td>[s uə o b̞ e ɾ ɒ k͡p̚ a ɾ ɨ k͡p̚ uə o]<br>[s o uə b ɾ e k a ɾ ɡ o]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>51576</th>
#       <td>tecnicismo</td>
#       <td>es186213</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[ð e k ʌ m i s i m a]<br>[ʔ e t͡ɕ iː ŋ m e ɪ tɕ i ʂ ɻ̩ m o]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>53070</th>
#       <td>traqueteo</td>
#       <td>es192086</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[t̪ ɾ a ɪ k e iː e t iː j o uə]<br>[k͡p̚ ɛ ɾ a ɡ̤ e t i]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>42225</th>
#       <td>polvareda</td>
#       <td>es152433</td>
#       <td>es.Argentina-es.Castellano</td>
#       <td>[uə o uə b̞ a lʲ ʌ ð ɪ]<br>[b̞ uə l̪ lʲ ɪ b ɒ ɾ i e tʂ ɒ ŋ]</td>
#       <td>19.0</td>
#     </tr>
#     <tr>
#       <th>14164</th>
#       <td>conveniente</td>
#       <td>es050866</td>
#       <td>es.Argentina-es.Mexico</td>
#       <td>[k o uː v e ɲ j æ n t e]<br>[k͡p̚ uə ɒ ɳ ɴ b̥ e ɪ n i j ə n t̪ e]</td>
#       <td>19.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
from IPython.display import Audio, display, Markdown
from pathlib import Path

def play_audio(word, accent, path_prefix="output/words_wav/es/sr16000"):
    # find wav file containing word and accent:
    audio_files = list(Path(path_prefix).glob(f"{word}_*{accent}.wav"))
    if not audio_files:
        print(f"No audio files found for {word} with accent {accent}")
        return
    audio_path = audio_files[0]  # Take the first matching file
    try:
        display(Markdown(f"**{word}** ({accent})"))
        display(Audio(audio_path, autoplay=True))
    except FileNotFoundError:
        print(f"Audio file not found: {audio_path}")

# %%
play_audio("taberna", "es.Mexico")
play_audio("caverna", "es.Mexico")
play_audio("taberna", "es.Argentina")
play_audio("caverna", "es.Argentina")
# Out:
# **taberna** (es.Mexico)
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# **caverna** (es.Mexico)
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# **taberna** (es.Argentina)
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# **caverna** (es.Argentina)
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
play_audio("w", "es.Argentina")
play_audio("w", "es.Castellano")
# Out:
# **w** (es.Argentina)
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# **w** (es.Castellano)
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mask = df_phones['word'].str.contains('caverna|taberna')
df_phones[mask].sort_values(["accent", "id"])
# Out:
#                                 file_name                         phone_list  \
# 44906   caverna_es036728_es.Argentina.wav                                [ɾ]
# 29094   taberna_es184465_es.Argentina.wav              [t, ɒ, b, e, ɾ, ɴ, ɪ]
# 35824  caverna_es036728_es.Castellano.wav     [t͡ɕ, ɒ, a, b̞, e, ɾ, ә, n, ɪ]
# 34710  taberna_es184465_es.Castellano.wav  [t͡ɕ, ɒ, p, i, ə, ɾ, ә, ŋ̟, d, ɒ]
# 28014      caverna_es036728_es.Mexico.wav           [t͡ɕ, a, b̞, e, ɾ, ʔ, ɪ]
# 24292      taberna_es184465_es.Mexico.wav          [t, ɒ, b̞, e, ɴ, ɾ, m, ɒ]
#
#           word        id         accent                  phones
# 44906  caverna  es036728   es.Argentina                       ɾ
# 29094  taberna  es184465   es.Argentina           t ɒ b e ɾ ɴ ɪ
# 35824  caverna  es036728  es.Castellano    t͡ɕ ɒ a b̞ e ɾ ә n ɪ
# 34710  taberna  es184465  es.Castellano  t͡ɕ ɒ p i ə ɾ ә ŋ̟ d ɒ
# 28014  caverna  es036728      es.Mexico        t͡ɕ a b̞ e ɾ ʔ ɪ
# 24292  taberna  es184465      es.Mexico        t ɒ b̞ e ɴ ɾ m ɒ

# %%
# from gruut_ipa import Pronunciation

# # ipa_string = "ˈjɛs|ˈt͡ʃuːz aɪpiːeɪ‖"
# ipa_string = "l̪ l a t͡ɕ t̪ i k͡p̚ o"

# res = Pronunciation.from_string(ipa_string).phones
